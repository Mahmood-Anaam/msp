# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmood-Anaam/msp/blob/main/notebooks/evaluate_msp_with_lm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluate

# %% [markdown]
# Evaluate MSP models using the AVSRCocktail-compatible protocol.

# %% [markdown]
# ## Install

# %%
# !pip install https://github.com/kpu/kenlm/archive/master.zip pyctcdecode --q

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
from pyctcdecode.constants import (
    DEFAULT_BEAM_WIDTH,
    DEFAULT_HOTWORD_WEIGHT,
    DEFAULT_MIN_TOKEN_LOGP,
    DEFAULT_PRUNE_LOGP,
)

DEFAULT_BEAM_WIDTH, DEFAULT_HOTWORD_WEIGHT, DEFAULT_MIN_TOKEN_LOGP, DEFAULT_PRUNE_LOGP
# Out:
# (100, 10.0, -5.0, -10.0)

# %%
# !git clone https://github.com/Mahmood-Anaam/msp.git
# Out:
# Cloning into '/content/msp'...
# remote: Enumerating objects: 1103, done.
# remote: Counting objects: 100% (306/306), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 1103 (delta 220), reused 208 (delta 171), pack-reused 797 (from 1)
# Receiving objects: 100% (1103/1103), 4.90 MiB | 18.64 MiB/s, done.
# Resolving deltas: 100% (672/672), done.

# %%
# !pip install -e /content/msp/ --q

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
from huggingface_hub import login
from google.colab import userdata

HF_USERNAME = userdata.get('HF_USERNAME')
HF_TOKEN = userdata.get('HF_TOKEN')

login(HF_TOKEN)

# %% [markdown]
# ## MSP-VSR

# %% [markdown]
# ### LRS2

# %%
# !evaluate \
  --model_type msp_visual \
  --model_name_or_path MahmoodAnaam/MSP-VSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name lrs2 \
  --streaming_dataset true \
  --set_id "test" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# config.json: 100% 1.57k/1.57k [00:00<00:00, 2.60MB/s]
# tokenizer_config.json: 100% 181/181 [00:00<00:00, 1.14MB/s]
# vocab.json: 100% 292/292 [00:00<00:00, 2.27MB/s]
# special_tokens_map.json: 100% 85.0/85.0 [00:00<00:00, 562kB/s]
# Loading MSP model: MahmoodAnaam/MSP-VSR
# Model type: msp_visual
# config.json: 100% 5.48k/5.48k [00:00<00:00, 12.5MB/s]
# configuration_msp_visual.py: 100% 1.49k/1.49k [00:00<00:00, 5.08MB/s]
# configuration_avhubert.py: 100% 11.9k/11.9k [00:00<00:00, 27.3MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-VSR:
# - configuration_avhubert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-VSR:
# - configuration_msp_visual.py
# - configuration_avhubert.py
# ...

# %% [markdown]
# ### AVCocktail

# %%
# !evaluate \
  --model_type msp_visual \
  --model_name_or_path MahmoodAnaam/MSP-VSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name AVCocktail \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-VSR
# Model type: msp_visual
# Loading weights: 100% 538/538 [00:00<00:00, 5868.25it/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 9880.57it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Model loaded successfully.
#
# Evaluating AVCocktail/video_0
# README.md: 100% 26.8k/26.8k [00:00<00:00, 55.5MB/s]
#
# videos/video_0/asd-chunk-eval-0.tar: downloading bytes:  68% 18.2M/26.9M [00:01<00:00, 13.6MB/s,  406kB/s  ]
# videos/video_0/asd-chunk-eval-0.tar: downloading bytes: 100% 26.6M/26.6M [00:01<00:00, 14.8MB/s, 2.55MB/s  ]
# videos/video_0/asd-chunk-eval-0.tar: reconstructing file: 100% 26.9M/26.9M [00:01<00:00, 14.9MB/s, 2.58MB/s  ]
#
# videos/video_0/fixed-chunk-eval-0.tar: downloading bytes:  99% 29.2M/29.6M [00:07<00:00, 8.08MB/s, 2.12MB/s  ]
# ...

# %% [markdown]
# ## MSP-ASR

# %% [markdown]
# ### LRS2

# %%
# !evaluate \
  --model_type msp_audio \
  --model_name_or_path MahmoodAnaam/MSP-ASR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name lrs2 \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# config.json: 100% 1.57k/1.57k [00:00<00:00, 2.47MB/s]
# tokenizer_config.json: 100% 181/181 [00:00<00:00, 1.11MB/s]
# vocab.json: 100% 292/292 [00:00<00:00, 1.10MB/s]
# special_tokens_map.json: 100% 85.0/85.0 [00:00<00:00, 437kB/s]
# Loading MSP model: MahmoodAnaam/MSP-ASR
# Model type: msp_audio
# config.json: 100% 2.22k/2.22k [00:00<00:00, 6.07MB/s]
# configuration_msp_audio.py: 100% 6.14k/6.14k [00:00<00:00, 17.0MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-ASR:
# - configuration_msp_audio.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_msp_audio.py: 100% 6.38k/6.38k [00:00<00:00, 18.6MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-ASR:
# - modeling_msp_audio.py
# ...

# %% [markdown]
# ### AVCocktail

# %%
# !evaluate \
  --model_type msp_audio \
  --model_name_or_path MahmoodAnaam/MSP-ASR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name AVCocktail \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-ASR
# Model type: msp_audio
# Loading weights: 100% 424/424 [00:00<00:00, 6435.17it/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 2529.74it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Model loaded successfully.
#
# Evaluating AVCocktail/video_0
# Evaluating video_0/asd_chunk: 100% 21/21 [00:19<00:00,  1.06it/s]
# Evaluating video_0/fixed_chunk: 100% 29/29 [00:22<00:00,  1.31it/s]
# Evaluating video_0/gold_chunk: 100% 69/69 [00:26<00:00,  2.59it/s]
# WER video_0 asd_chunk: 0.8418
# WER video_0 fixed_chunk: 0.8502
# WER video_0 gold_chunk: 0.8434
#
# Evaluating AVCocktail/video_1
#
# videos/video_1/asd-chunk-eval-0.tar: downloading bytes:  81% 14.3M/17.8M [00:01<00:00, 23.4MB/s,  375kB/s  ]
# ...

# %% [markdown]
# ## MSP-AVSR

# %% [markdown]
# ### LRS2

# %% [markdown]
# #### audio & visual

# %%
# !evaluate \
  --model_type msp \
  --model_name_or_path MahmoodAnaam/MSP-AVSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name lrs2 \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-AVSR-E2E
# Model type: msp
# config.json: 100% 9.55k/9.55k [00:00<00:00, 18.9MB/s]
# configuration_msp.py: 100% 2.99k/2.99k [00:00<00:00, 10.6MB/s]
# configuration_msp_visual.py: 100% 1.54k/1.54k [00:00<00:00, 5.77MB/s]
# configuration_avhubert.py: 100% 12.2k/12.2k [00:00<00:00, 30.6MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_avhubert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_msp_visual.py
# - configuration_avhubert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %% [markdown]
# #### audio only

# %%
# !evaluate \
  --model_type msp \
  --modality msp_audio \
  --model_name_or_path MahmoodAnaam/MSP-AVSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name lrs2 \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-AVSR-E2E
# Model type: msp
# Loading weights: 100% 992/992 [00:00<00:00, 5315.77it/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 5526.09it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Model loaded successfully.
#
# Evaluating LRS2/test
# Resolving data files: 100% 502/502 [00:00<00:00, 15018.44it/s]
# Resolving data files: 100% 58/58 [00:00<00:00, 15121.19it/s]
# Evaluating LRS2: 1243it [03:19,  6.24it/s]
# WER test: 0.0410
#
# Evaluating LRS2/test_snr_n5_interferer_1
# Resolving data files: 100% 502/502 [00:00<00:00, 28402.97it/s]
# Resolving data files: 100% 58/58 [00:00<00:00, 262994.20it/s]
# Evaluating LRS2: 1243it [05:57,  3.48it/s]
# WER test_snr_n5_interferer_1: 0.9183
#
# Evaluating LRS2/test_snr_n5_interferer_2
# ...

# %% [markdown]
# #### visual only

# %%
# !evaluate \
  --model_type msp \
  --modality msp_visual \
  --model_name_or_path MahmoodAnaam/MSP-AVSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name lrs2 \
  --streaming_dataset true \
  --set_id "test" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-AVSR-E2E
# Model type: msp
# Loading weights: 100% 992/992 [00:00<00:00, 3182.68it/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 10070.36it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Model loaded successfully.
# Resolving data files: 100% 502/502 [00:00<00:00, 18707.60it/s]
# Resolving data files: 100% 58/58 [00:00<00:00, 3100.71it/s]
# Evaluating LRS2: 1243it [04:39,  4.44it/s]
# WER test: 0.3114

# %% [markdown]
# ### AVCocktail

# %% [markdown]
# #### audio & visual

# %%
# !evaluate \
  --model_type msp \
  --model_name_or_path MahmoodAnaam/MSP-AVSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name AVCocktail \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# config.json: 100% 1.57k/1.57k [00:00<00:00, 2.60MB/s]
# tokenizer_config.json: 100% 181/181 [00:00<00:00, 438kB/s]
# vocab.json: 100% 292/292 [00:00<00:00, 2.03MB/s]
# special_tokens_map.json: 100% 85.0/85.0 [00:00<00:00, 597kB/s]
# Loading MSP model: MahmoodAnaam/MSP-AVSR-E2E
# Model type: msp
# config.json: 100% 9.55k/9.55k [00:00<00:00, 14.9MB/s]
# configuration_msp.py: 100% 2.99k/2.99k [00:00<00:00, 10.4MB/s]
# configuration_msp_audio.py: 100% 6.30k/6.30k [00:00<00:00, 19.6MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_msp_audio.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# configuration_msp_visual.py: 100% 1.54k/1.54k [00:00<00:00, 6.48MB/s]
# configuration_avhubert.py: 100% 12.2k/12.2k [00:00<00:00, 31.4MB/s]
# ...

# %% [markdown]
# #### audio only

# %%
# !evaluate \
  --model_type msp \
  --modality msp_audio \
  --model_name_or_path MahmoodAnaam/MSP-AVSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name AVCocktail \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-AVSR-E2E
# Model type: msp
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_avhubert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_msp_visual.py
# - configuration_avhubert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_msp_audio.py
# ...

# %% [markdown]
# #### visual only

# %%
# !evaluate \
  --model_type msp \
  --modality msp_visual \
  --model_name_or_path MahmoodAnaam/MSP-AVSR \
  --processor_name_or_path MahmoodAnaam/MSP-Processor-With-LM \
  --dataset_name AVCocktail \
  --streaming_dataset true \
  --set_id "*" \
  --cache_dir /workspace/cache/huggingface \
  --dataset_cache_dir /workspace/data/cache \
  --device cuda
# Out:
# Loading MSP model: MahmoodAnaam/MSP-AVSR-E2E
# Model type: msp
# config.json: 100% 9.55k/9.55k [00:00<00:00, 5.57MB/s]
# configuration_msp.py: 100% 2.99k/2.99k [00:00<00:00, 7.64MB/s]
# configuration_msp_audio.py: 100% 6.30k/6.30k [00:00<00:00, 15.8MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_msp_audio.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# configuration_msp_visual.py: 100% 1.54k/1.54k [00:00<00:00, 4.23MB/s]
# configuration_avhubert.py: 100% 12.2k/12.2k [00:00<00:00, 24.7MB/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/MahmoodAnaam/MSP-AVSR-E2E:
# - configuration_avhubert.py
# ...
